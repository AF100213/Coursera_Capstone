# %% [markdown]
# # Introduction Opening a new restaurant in New York city

# %% [markdown]
# Opening a new restaurant could prove to be a challenge in any
# city in the world, The aim of this project is to determine
# the balance between location, attraction and competition. We want the
# location to be suitable for the restaurant, while trying to avoid unnecessary
# Competition to ensure the profit is maximized.
# To find the best spot, we need to analyze the neighborhoods of  New York.

# %% [markdown]
# # Data Description

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing restaurants in the neighborhood (any type of restaurant)
# * neighborhood Gross Domestic Product
# * neighborhood Population
#
# To complete this analysis, we will rely on Foursquare API which is well
# documented. It will enable us to determine any competitors and their
# locations. It is a simple matter of querying the data and putting them in
# data frames using the Pandas library in Python. The results are in json
# format

# %% [markdown]
# # Methodology

# %% [markdown]
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria.
# Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# First define the criteria for the best place:
#
# ##   Rating_of_place = (Gross Domestic Product * Population ) / number_of_restaurants
#
# Detailed calculations in file my_data_00.ipynb

# %% [markdown]
# # RESULTS

# %% [markdown]
# first we have table, sort by rating (best place for restaurant) and we can
# pick first rows to continue research by adding new
# criterias to narrow down your choice to the end result.

# %% [markdown]
# ![P001.jpg](attachment:P001.jpg)

# %% [markdown]
# ![P001.jpg](P001.jpg)

# %% [markdown]
# # first 6 best places on map

# %% [markdown]
# ![P002.jpg](attachment:P002.jpg)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Finding the best location for a restaurant is no easy task.
# However, relying on available data, we made this task a lot easier.
# Final decission on optimal restaurant location will be made by stakeholders based on specific characteristics
# of neighborhoods and locations in every recommended zone, taking into consideration additional
# factors like attractiveness of each location (proximity to park or water), levels of noise / proximity
# to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
